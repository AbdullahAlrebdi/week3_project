# %%
# !pip install geopy
# Out:
# ...
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 679.4 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.6 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import geopy

# %%
# install_certifi.py
#
# sample script to install or update a set of default Root Certificates
# for the ssl module.  Uses the certificates provided by the certifi package:
#       https://pypi.python.org/pypi/certifi

import os
import os.path
import ssl
import stat
import subprocess
import sys

STAT_0o775 = ( stat.S_IRUSR | stat.S_IWUSR | stat.S_IXUSR
             | stat.S_IRGRP | stat.S_IWGRP | stat.S_IXGRP
             | stat.S_IROTH |                stat.S_IXOTH )


def main():
    openssl_dir, openssl_cafile = os.path.split(
        ssl.get_default_verify_paths().openssl_cafile)

    print(" -- pip install --upgrade certifi")
    subprocess.check_call([sys.executable,
        "-E", "-s", "-m", "pip", "install", "--upgrade", "certifi"])

    import certifi

    # change working directory to the default SSL directory
    os.chdir(openssl_dir)
    relpath_to_certifi_cafile = os.path.relpath(certifi.where())
    print(" -- removing any existing file or link")
    try:
        os.remove(openssl_cafile)
    except FileNotFoundError:
        pass
    print(" -- creating symlink to certifi certificate bundle")
    os.symlink(relpath_to_certifi_cafile, openssl_cafile)
    print(" -- setting permissions")
    os.chmod(openssl_cafile, STAT_0o775)
    print(" -- update complete")

if __name__ == '__main__':
    main()
# Out:
#  -- pip install --upgrade certifi
# ...
#   Obtaining dependency information for certifi from https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 789.0 kB/s eta 0:00:001m752.0 kB/s eta 0:00:01
# ...
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.5.7
#     Uninstalling certifi-2023.5.7:
#       Successfully uninstalled certifi-2023.5.7
# ...
#  -- removing any existing file or link
#  -- creating symlink to certifi certificate bundle
#  -- setting permissions
#  -- update complete
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from geopy.geocoders import Nominatim

def get_district(city, neighborhood):
    # Initialize geocoder
    geolocator = Nominatim(user_agent="district_locator")
    
    # Construct the query string
    location_query = f"{neighborhood}, {city}"
    
    # Perform geocoding lookup
   

    location = geolocator.geocode(location_query, exactly_one=True)
    
    # Extract address components
    if location:
        address = location
        print(type(address))
        
        # Try to find the district
        district = None
        for key in ['suburb', 'city_district', 'county']:
            if key in address:
                district = address[key]
                break
        
        return district
    else:
        return None

# Example city and neighborhood names
city_name = 'New York'
neighborhood_name = 'Lower East Side'
print(city_name)
print(neighborhood_name)


# Call the function to get the district
neighborhood_district = get_district(city_name, neighborhood_name)

# Print the result
if neighborhood_district:
    print(f"The neighborhood '{neighborhood_name}' in {city_name} is located in the district: {neighborhood_district}")
else:
    print("District information not found for the given city and neighborhood.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from geopy.geocoders import Nominatim
#       3 def get_district(city, neighborhood):
#       4     # Initialize geocoder
#       5     geolocator = Nominatim(user_agent="district_locator")
#
# ModuleNotFoundError: No module named 'geopy'

# %% [markdown]
# #### 1. Data Loading and Initial Exploration:
# - Load the selected dataset into your preferred data analysis environment.
# - Explore the structure of the dataset (number of rows and columns, data types, etc.).
# - Examine the first few rows of the dataset to understand its contents.

# %% [markdown]
# ## Column Descriptions
#
# ### columns of Reviews data

# %%
df_reviews_dic = pd.read_csv('../Airbnb Data/Reviews_data_dictionary.csv')
df_reviews_dic
# Out:
#          Field  Description
# 0   listing_id   Listing ID
# 1    review_id    Review ID
# 2         date  Review date
# 3  reviewer_id  Reviewer ID

# %% [markdown]
# ### Reading reviews data

# %%
df_reviews = pd.read_csv('../Airbnb Data/reviews.csv', index_col='review_id', parse_dates=['date'])
df_reviews.head()
# Out:
#            listing_id       date  reviewer_id
# review_id
# 330265172       11798 2018-09-30     11863072
# 330103585       15383 2018-09-30     39147453
# 329985788       16455 2018-09-30      1125378
# 330016899       17919 2018-09-30    172717984
# 329995638       26827 2018-09-30     17542859

# %%
df_reviews.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5373143 entries, 330265172 to 730320626
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   listing_id   5373143 non-null  int64
#  1   date         5373143 non-null  datetime64[ns]
#  2   reviewer_id  5373143 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 164.0 MB

# %%
df_reviews.describe()
# Out:
#          listing_id                           date   reviewer_id
# count  5.373143e+06                        5373143  5.373143e+06
# mean   1.602989e+07  2018-06-26 06:57:54.259292160  9.808133e+07
# min    2.577000e+03            2008-11-16 00:00:00  1.000000e+00
# 25%    5.332708e+06            2017-07-04 00:00:00  2.390206e+07
# 50%    1.450814e+07            2018-10-29 00:00:00  6.697814e+07
# 75%    2.414496e+07            2019-09-21 00:00:00  1.528936e+08
# max    4.826387e+07            2021-03-01 00:00:00  3.903385e+08
# std    1.198676e+07                            NaN  9.080596e+07

# %% [markdown]
# ### columns of Listings data

# %%
df_listing_dic = pd.read_csv('../Airbnb Data/Listings_data_dictionary.csv')
df_listing_dic
# Out:
#                           Field
# 0                    listing_id  \
# 1                          name
# 2                       host_id
# 3                    host_since
# 4                 host_location
# 5            host_response_time
# 6            host_response_rate
# 7          host_acceptance_rate
# 8             host_is_superhost
# 9     host_total_listings_count
# 10         host_has_profile_pic
# 11       host_identity_verified
# 12                neighbourhood
# 13                     district
# 14                         city
# 15                     latitude
# 16                    longitude
# 17                property_type
# 18                    room_type
# 19                 accommodates
# 20                     bedrooms
# 21                    amenities
# 22                        price
# 23               minimum_nights
# 24               maximum_nights
# 25         review_scores_rating
# 26       review_scores_accuracy
# 27    review_scores_cleanliness
# ...

# %% [markdown]
# ### Reading listings data

# %%
df_listings = pd.read_csv('../Airbnb Data/Listings.csv', encoding='latin', index_col = "listing_id",parse_dates=['host_since'])
pd.options.display.max_columns = None
df_listings.head()
# Out:
# /var/folders/xz/g8xpv2m149q45f7_gzw2vmkm0000gn/T/ipykernel_35314/2160722555.py:1: DtypeWarning: Columns (5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listings = pd.read_csv('../Airbnb Data/Listings.csv', encoding='latin', index_col = "listing_id",parse_dates=['host_since'])
#                                                         name   host_id
# listing_id
# 281420        Beautiful Flat in le Village Montmartre, Paris   1466919  \
# 3705183                      39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 4082273                  Lovely apartment with Terrace, 60m2  19252768
# 4797344                  Cosy studio (close to Eiffel tower)  10668311
# 4823489     Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#            host_since                 host_location host_response_time
# listing_id
# 281420     2011-12-03  Paris, Ile-de-France, France                NaN  \
# ...

# %%
df_listings[df_listings['neighbourhood']=='Lower East Side']
# Out:
# name                             0
# host_id                          0
# host_since                       0
# host_location                    1
# host_response_time             395
# host_response_rate             395
# host_acceptance_rate           310
# host_is_superhost                0
# host_total_listings_count        0
# host_has_profile_pic             0
# host_identity_verified           0
# neighbourhood                    0
# district                         0
# city                             0
# latitude                         0
# longitude                        0
# property_type                    0
# room_type                        0
# accommodates                     0
# bedrooms                        67
# amenities                        0
# price                            0
# minimum_nights                   0
# maximum_nights                   0
# review_scores_rating           196
# review_scores_accuracy         198
# review_scores_cleanliness      198
# ...

# %%
df_listings[df_listings['district'].notnull()][['city','neighbourhood','district']]
# Out:
#                 city    neighbourhood   district
# listing_id
# 3457770     New York  Lower East Side  Manhattan
# 4173751     New York           Harlem  Manhattan
# 4259427     New York    Crown Heights   Brooklyn
# 4370230     New York           Nolita  Manhattan
# 5286096     New York          Midtown  Manhattan
# ...              ...              ...        ...
# 46546450    New York     Williamsburg   Brooklyn
# 47001322    New York     Williamsburg   Brooklyn
# 47015466    New York     West Village  Manhattan
# 47432094    New York         Bushwick   Brooklyn
# 18617195    New York     Williamsburg   Brooklyn
#
# [37012 rows x 3 columns]

# %%
df_listings[df_listings[df_listings['neighbourhood'] == 'Elysee']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df_listings[df_listings[df_listings['neighbourhood'] == 'Elysee']]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3747, in DataFrame.__getitem__(self, key)
#    3745 # Do we have a (boolean) DataFrame?
#    3746 if isinstance(key, DataFrame):
# -> 3747     return self.where(key)
#    3749 # Do we have a (boolean) 1d indexer?
#    3750 if com.is_bool_indexer(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:11527, in DataFrame.where(self, cond, other, inplace, axis, level)
#   11518 def where(
#   11519     self,
#   11520     cond,
#    (...)
#   11525     level: Level = None,
#   11526 ) -> DataFrame | None:
# > 11527     return super().where(
#   11528         cond,
# ...

# %%
df_listings[df_listings['neighbourhood'].notnull() & df_listings['district'].notnull()][['neighbourhood','district']].values[0]
# Out:
# array(['Lower East Side', 'Manhattan'], dtype=object)

# %%
list(df_listings['neighbourhood'].unique())
# Out:
# ['Buttes-Montmartre',
#  'Elysee',
#  'Vaugirard',
#  'Passy',
#  'Temple',
#  'Popincourt',
#  'Buttes-Chaumont',
#  'Opera',
#  'Gobelins',
#  'Hotel-de-Ville',
#  'Pantheon',
#  'Enclos-St-Laurent',
#  'Batignolles-Monceau',
#  'Luxembourg',
#  'Reuilly',
#  'Menilmontant',
#  'Observatoire',
#  'Palais-Bourbon',
#  'Bourse',
#  'Louvre',
#  'Lower East Side',
#  'Harlem',
#  'Crown Heights',
#  'Nolita',
#  'Midtown',
#  'Greenwich Village',
#  'Williamsburg',
#  'East Village',
#  'Upper West Side',
#  "Hell's Kitchen",
#  'Park Slope',
#  'Vadhana',
#  'Leblon',
#  'Waverley',
#  'Adalar',
#  'I Centro Storico',
#  'Chinatown',
#  'Upper East Side',
#  'Southern',
#  'Uskudar',
#  'II Parioli/Nomentano',
#  'IV Tiburtina',
#  'V Prenestino/Centocelle',
#  'Columbia St',
#  'Inwood',
#  'Bedford-Stuyvesant',
#  'Astoria',
#  'Little Italy',
#  'Fort Greene',
#  'Bushwick',
#  'East Harlem',
#  'Washington Heights',
#  'Woodside',
#  'Greenpoint',
#  'Ditmars Steinway',
# ...

# %%
df_listings['instant_bookable'].value_counts()
# Out:
# instant_bookable
# f    164105
# t    115607
# Name: count, dtype: int64

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 279712 entries, 281420 to 40219504
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   name                         279537 non-null  object
#  1   host_id                      279712 non-null  int64
#  2   host_since                   279547 non-null  datetime64[ns]
#  3   host_location                278872 non-null  object
#  4   host_response_time           150930 non-null  object
#  5   host_response_rate           150930 non-null  float64
#  6   host_acceptance_rate         166625 non-null  float64
#  7   host_is_superhost            279547 non-null  object
#  8   host_total_listings_count    279547 non-null  float64
#  9   host_has_profile_pic         279547 non-null  object
#  10  host_identity_verified       279547 non-null  object
#  11  neighbourhood                279712 non-null  object
# ...

# %%
df_listings.describe()
# Out:
#             host_id                     host_since  host_response_rate  \
# count  2.797120e+05                         279547       150930.000000
# mean   1.081658e+08  2016-04-11 13:01:44.994151680            0.865939
# min    1.822000e+03            2008-08-12 00:00:00            0.000000
# 25%    1.720656e+07            2014-07-01 00:00:00            0.900000
# 50%    5.826911e+07            2016-02-14 00:00:00            1.000000
# 75%    1.832853e+08            2018-04-09 00:00:00            1.000000
# max    3.901874e+08            2021-02-26 00:00:00            1.000000
# std    1.108570e+08                            NaN            0.283744
#
#        host_acceptance_rate  host_total_listings_count       latitude  \
# count         166625.000000              279547.000000  279712.000000
# mean               0.827168                  24.581612      18.761862
# min                0.000000                   0.000000     -34.264400
# ...

# %% [markdown]
# #### 2. Data Cleaning:
# - Handle missing values appropriately (e.g., imputation, deletion, etc.).
# - Check for and handle any duplicate entries.
# - Convert categorical variables into the appropriate data type if necessary.

# %% [markdown]
# -renaming "date" to "review_date"
#
# -making sure no null values

# %%
df_reviews.rename(columns={'date': "review_date"}, inplace=True)
df_reviews.isnull().sum()
# Out:
# listing_id     0
# review_date    0
# reviewer_id    0
# dtype: int64

# %% [markdown]
# Check duplicated and droping them

# %%
df_reviews.duplicated().sum()
# Out:
# 311

# %%
df_reviews.drop_duplicates(inplace=True)
df_reviews.duplicated().sum()
# Out:
# 0

# %%
df_listings.duplicated().sum()
# Out:
# 27

# %%
df_listings.drop_duplicates(inplace=True)
df_listings.duplicated().sum()
# Out:
# 0

# %%
# df_listings['city'].value_counts()
# df_listings['host_since']

# %%
df_listings.isnull().sum()
# Out:
# name                              175
# host_id                             0
# host_since                        165
# host_location                     840
# host_response_time             128771
# host_response_rate             128771
# host_acceptance_rate           113076
# host_is_superhost                 165
# host_total_listings_count         165
# host_has_profile_pic              165
# host_identity_verified            165
# neighbourhood                       0
# district                       242679
# city                                0
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# bedrooms                        29434
# amenities                           0
# price                               0
# minimum_nights                      0
# maximum_nights                      0
# review_scores_rating            91378
# ...

# %% [markdown]
# Q1: what effects pricing?
#
# Q2:

# %%
# df_listings_copy = df_listings.copy()
# df_listing_dist = df_listings[df_listings['district'].notna()].copy()

# %%
df_listings.drop(columns=
                 ['host_response_time' , 'host_response_rate', 'host_acceptance_rate','district' ,
"review_scores_rating",
"review_scores_accuracy",
"review_scores_cleanliness",
"review_scores_checkin",
"review_scores_communication",
"review_scores_location",
"review_scores_value"] , inplace=True)

# %%
df_listings.isnull().sum()
# Out:
# name                           175
# host_id                          0
# host_since                     165
# host_location                  840
# host_is_superhost              165
# host_total_listings_count      165
# host_has_profile_pic           165
# host_identity_verified         165
# neighbourhood                    0
# city                             0
# latitude                         0
# longitude                        0
# property_type                    0
# room_type                        0
# accommodates                     0
# bedrooms                     29434
# amenities                        0
# price                            0
# minimum_nights                   0
# maximum_nights                   0
# instant_bookable                 0
# dtype: int64

# %%
df_listings.dropna(inplace=True)
df_listings.isnull().sum()
# Out:
# name                         0
# host_id                      0
# host_since                   0
# host_location                0
# host_is_superhost            0
# host_total_listings_count    0
# host_has_profile_pic         0
# host_identity_verified       0
# neighbourhood                0
# city                         0
# latitude                     0
# longitude                    0
# property_type                0
# room_type                    0
# accommodates                 0
# bedrooms                     0
# amenities                    0
# price                        0
# minimum_nights               0
# maximum_nights               0
# instant_bookable             0
# dtype: int64

# %% [markdown]
# #### 4. Feature Engineering:
# - Create new features that might be useful for analysis (e.g., average rating, occupancy rate, etc.).
# - Encode categorical variables if necessary (e.g., one-hot encoding, label encoding, etc.).

# %% [markdown]
# #### 5. Hypothesis Testing (Optional):
# - Formulate hypotheses related to the dataset based on different factors.
# - Perform statistical tests (e.g., t-test, ANOVA, etc.) to test these hypotheses.

# %% [markdown]
# #### 6. Conclusion:
# - Summarize the findings from the exploratory data analysis.
# - Discuss any insights or patterns observed in the data.
# - Make recommendations based on the analysis conducted.
